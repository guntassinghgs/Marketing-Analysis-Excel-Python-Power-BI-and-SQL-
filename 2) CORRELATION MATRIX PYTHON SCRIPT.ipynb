# %%
import pandas as pd

# %%
file_path = r'C:\Users\singgunt\Desktop\Coding ninjas\Coding ninjas data analysis\HACKATHON\1. SEP 2025 HACKATHON\KAG_conversion_data_raw (1).csv'

data = pd.read_csv(file_path)

print(data.head())
print(data.info())
# Out:
#     ad_id  xyz_campaign_id  fb_campaign_id    age gender  interest  \
# 0  708746              916          103916  30-34      M        15
# 1  708749              916          103917  30-34      M        16
# 2  708771              916          103920  30-34      M        20
# 3  708815              916          103928  30-34      M        28
# 4  708818              916          103928  30-34      M        28
#
#    Impressions  Clicks     Spent  Total_Conversion  Approved_Conversion
# 0         7350       1  1.430000                 2                    1
# 1        17861       2  1.820000                 2                    0
# 2          693       1  1.315966                 1                    0
# 3         4259       1  1.250000                 1                    0
# 4         4133       1  1.290000                 1                    1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 11 columns):
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your data is loaded into 'data'
columns = ['Impressions', 'Clicks', 'Spent', 'Total_Conversion', 'Approved_Conversion']
corr = data[columns].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
